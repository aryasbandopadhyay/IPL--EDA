# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
match=pd.read_csv('matches.csv')
delivery=pd.read_csv('deliveries.csv')

# %%
match.shape
# Out:
# (636, 18)

# %%
match.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
match.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %%
delivery.shape
# Out:
# (150460, 21)

# %%
delivery.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
delivery.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over   ...    bye_runs  \
# ...

# %%
match.shape[0]
#number of matches
# Out:
# 636

# %%
#total no of seasons
matches=match.groupby('season')
len(matches)
# Out:
# 10

# %%
match['season'].nunique()
#total no of seasons
# Out:
# 10

# %%
set(match['team1'].tolist()+match['team2'].tolist())
#no of teams
# Out:
# {'Chennai Super Kings',
#  'Deccan Chargers',
#  'Delhi Daredevils',
#  'Gujarat Lions',
#  'Kings XI Punjab',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Pune Warriors',
#  'Rajasthan Royals',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiants',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad'}

# %%
match['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
sns.countplot('season',data=match)

# %%
sns.countplot('venue',data=match)
plt.xticks(rotation='vertical')
match['venue'].value_counts()
# Out:
# M Chinnaswamy Stadium                                   66
# Eden Gardens                                            61
# Feroz Shah Kotla                                        60
# Wankhede Stadium                                        57
# Rajiv Gandhi International Stadium, Uppal               49
# MA Chidambaram Stadium, Chepauk                         48
# Punjab Cricket Association Stadium, Mohali              35
# Sawai Mansingh Stadium                                  33
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Maharashtra Cricket Association Stadium                 15
# Kingsmead                                               15
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Brabourne Stadium                                       11
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %%
(match['team1'].value_counts()+match['team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kolkata Knight Riders          148
# Kings XI Punjab                148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# dtype: int64

# %%
match['winner'].value_counts().head(1).index[0]
# Out:
# 'Mumbai Indians'

# %%
delivery.head(1)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over   ...    bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0   ...           0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 0            0            0             0             0           0
#
#    total_runs  player_dismissed dismissal_kind fielder
# 0           0               NaN            NaN     NaN
#
# [1 rows x 21 columns]

# %%
de=delivery.groupby('batsman')

# %%
(de['batsman_runs'].sum()).sort_values(ascending=False).head(10)
# Out:
# batsman
# SK Raina          4548
# V Kohli           4423
# RG Sharma         4207
# G Gambhir         4132
# DA Warner         4014
# RV Uthappa        3778
# CH Gayle          3651
# S Dhawan          3561
# MS Dhoni          3560
# AB de Villiers    3486
# Name: batsman_runs, dtype: int64

# %%
mask=delivery['batsman_runs']==6
new_delivery=delivery[mask]

# %%
new_delivery.shape[0]
# Out:
# 6523

# %%
(new_delivery.groupby('batsman')['batsman_runs'].count()).sort_values(ascending=False).head(10)
# Out:
# batsman
# CH Gayle          266
# SK Raina          174
# RG Sharma         173
# DA Warner         160
# V Kohli           160
# AB de Villiers    158
# MS Dhoni          156
# YK Pathan         149
# KA Pollard        148
# Yuvraj Singh      141
# Name: batsman_runs, dtype: int64

# %%
vk=delivery[delivery['batsman']=='RG Sharma']
(vk.groupby('bowling_team')['batsman_runs'].count()).sort_values(ascending=False).head(10)
# Out:
# bowling_team
# Kolkata Knight Riders          525
# Delhi Daredevils               497
# Chennai Super Kings            439
# Royal Challengers Bangalore    410
# Kings XI Punjab                382
# Rajasthan Royals               332
# Deccan Chargers                140
# Sunrisers Hyderabad            125
# Pune Warriors                  123
# Mumbai Indians                  95
# Name: batsman_runs, dtype: int64

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over   ...    bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0   ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0   ...           0
# 2     3  DA Warner    S Dhawan  TS Mills              0   ...           0
# 3     4  DA Warner    S Dhawan  TS Mills              0   ...           0
# 4     5  DA Warner    S Dhawan  TS Mills              0   ...           0
#
# ...

# %%
match.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
def run_scored(batsman_name):
    vk=delivery[delivery['batsman']==batsman_name]
    return vk.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).head(1).index[0]

# %%
run_scored('RG Sharma')
# Out:
# 'Kolkata Knight Riders'

# %%
match.drop_duplicates('season',keep='last')[['season','winner']].sort_values('season')
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %%
delivery['dismissal_kind'].value_counts()
# Out:
# caught                   4373
# bowled                   1382
# run out                   755
# lbw                       455
# stumped                   243
# caught and bowled         211
# retired hurt                9
# hit wicket                  9
# obstructing the field       1
# Name: dismissal_kind, dtype: int64

# %%
out=['caught','bowled','lbw','stumped','caught and bowled','hit wicket']
bowler_dismissal=delivery[delivery['dismissal_kind'].isin(out)]

# %%
bowler_dismissal.groupby('bowler')['dismissal_kind'].count().sort_values(ascending=False)
# Out:
# bowler
# SL Malinga          154
# A Mishra            134
# Harbhajan Singh     127
# PP Chawla           126
# DJ Bravo            122
# B Kumar             111
# A Nehra             106
# R Vinay Kumar       103
# Z Khan              102
# R Ashwin            100
# SP Narine            95
# DW Steyn             92
# UT Yadav             91
# RP Singh             90
# P Kumar              90
# PP Ojha              89
# SR Watson            86
# JA Morkel            85
# MM Sharma            83
# RA Jadeja            82
# IK Pathan            80
# M Morkel             77
# L Balaji             76
# DS Kulkarni          76
# MM Patel             74
# Sandeep Sharma       71
# R Bhatia             71
# YS Chahal            70
# AB Dinda             69
# SK Trivedi           65
#                    ...
# SS Mundhe             1
# SS Agarwal            1
# GS Sandhu             1
# JDS Neesham           1
# PM Sarvesh Kumar      1
# SB Joshi              1
# LMP Simmons           1
# ...

# %%
new_match=match[['id','season']]
new_match.head(3)
# Out:
#    id  season
# 0   1    2017
# 1   2    2017
# 2   3    2017

# %%
orange_cap=new_match.merge(delivery,left_on='id',right_on='match_id')

# %%
orange_cap.groupby(['season','batsman'])['batsman_runs'].sum().sort_values()
# Out:
# season  batsman
# 2010    YA Abdulla           0
# 2008    S Sreesanth          0
# 2014    BE Hendricks         0
# 2009    C Nanda              0
# 2008    U Kaul               0
# 2010    CK Langeveldt        0
# 2011    MJ Lumb              0
# 2009    BAW Mendis           0
# 2016    A Zampa              0
# 2009    DW Steyn             0
# 2011    DE Bollinger         0
#         MS Gony              0
# 2010    S Ladda              0
# 2013    MM Sharma            0
#         S Anirudha           0
# 2011    MM Patel             0
# 2017    MM Patel             0
# 2010    Harmeet Singh        0
# 2008    L Balaji             0
#         MM Patel             0
# 2012    S Nadeem             0
#         RR Bhatkal           0
#         Sunny Gupta          0
# 2016    M Ashwin             0
# 2017    Imran Tahir          0
# 2011    JDP Oram             0
# 2017    CJ Jordan            0
# 2008    M Muralitharan       0
# 2011    Joginder Sharma      0
# ...

# %%
orange_cap=orange_cap.groupby(['season','batsman'])['batsman_runs'].sum().reset_index()
orange_cap=orange_cap.sort_values('batsman_runs',ascending=False)
orange_cap.drop_duplicates('season',keep='first').sort_values('season')
# Out:
#       season       batsman  batsman_runs
# 115     2008      SE Marsh           616
# 229     2009     ML Hayden           572
# 446     2010  SR Tendulkar           618
# 502     2011      CH Gayle           608
# 684     2012      CH Gayle           733
# 910     2013    MEK Hussey           733
# 1088    2014    RV Uthappa           660
# 1148    2015     DA Warner           562
# 1383    2016       V Kohli           973
# 1422    2017     DA Warner           641

# %%
heat_map=delivery[delivery['batsman_runs']==6]

# %%
x=heat_map.pivot_table(index='over',columns='batting_team',values='batsman_runs',aggfunc='mean')
sns.heatmap(x,cmap='winter')

# %%
y=delivery.pivot_table(index='over',columns='batting_team',values='total_runs',aggfunc='mean')
sns.heatmap(y,cmap='winter')

# %%
delivery
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
mask=delivery.groupby('batsman')['ball'].count().reset_index()
mask2=delivery.groupby('batsman')['batsman_runs'].sum().reset_index()
mask3=mask.merge(mask2,left_on='batsman',right_on='batsman')
mask4=mask3[mask3['ball']>200]
mask5=delivery[delivery['over']>15]
mask5=mask5.groupby('batsman')['batsman_runs'].sum().reset_index()
mask6=mask4.merge(mask5,left_on='batsman',right_on='batsman')
mask7=delivery[delivery['over']>=16]
mask8=mask7.groupby('batsman')['ball'].count().reset_index()
mask9=mask6.merge(mask8,left_on='batsman',right_on='batsman')

mask9['batsman_runs_x']=mask9['batsman_runs_y']/mask9['ball_y']
mask9.sort_values('batsman_runs_x',ascending=False)
# Out:
#              batsman  ball_x  batsman_runs_x  batsman_runs_y  ball_y
# 46           HM Amla     418        2.259259             122      54
# 77           M Vohra     750        2.214286              62      28
# 78        MA Agarwal     692        2.152174              99      46
# 3     AB de Villiers    2402        2.110526            1203     570
# 97       PC Valthaty     432        2.090909              46      22
# 133         V Sehwag    1833        2.085714              73      35
# 21          CH Gayle    2532        2.080808             412     198
# 52        JC Buttler     375        2.050000             123      60
# 4       AC Gilchrist    1555        1.968750              63      32
# 90            N Rana     355        1.900000              57      30
# 26         DA Warner    2902        1.894737             432     228
# 81        MEK Hussey    1648        1.891304             261     138
# 25         DA Miller    1135        1.866667             672     360
# ...

# %%
#correct_code
delivery['batsman'].nunique()
# Out:
# 461

# %%
mask5=delivery['batsman'].value_counts()>200
y=mask5[mask5].index.tolist()

# %%
maski=delivery['batsman'].isin(y)
z=delivery[maski]
z=z[z['over']>=16]
z.shape
# Out:
# (26537, 21)

# %%
m=z.groupby('batsman')['batsman_runs'].sum()

# %%
n=z.groupby('batsman')['ball'].count()

# %%
(m/n).sort_values(ascending=False)
# Out:
# batsman
# HM Amla            2.259259
# M Vohra            2.214286
# MA Agarwal         2.152174
# AB de Villiers     2.110526
# PC Valthaty        2.090909
# V Sehwag           2.085714
# CH Gayle           2.080808
# JC Buttler         2.050000
# AC Gilchrist       1.968750
# N Rana             1.900000
# DA Warner          1.894737
# MEK Hussey         1.891304
# DA Miller          1.866667
# CL White           1.824121
# GJ Maxwell         1.822430
# V Kohli            1.818681
# ML Hayden          1.811321
# BB McCullum        1.810000
# Q de Kock          1.800000
# KK Nair            1.787234
# B Chipli           1.785714
# SR Watson          1.777778
# SS Iyer            1.769231
# KP Pietersen       1.757143
# RG Sharma          1.756684
# DJ Hussey          1.752137
# SC Ganguly         1.743119
# CH Morris          1.742424
# M Vijay            1.736111
# RV Uthappa         1.734545
#                      ...
# MR Marsh           1.333333
# PA Patel           1.327273
# ...

# %%
delivery
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
bat=delivery.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10).reset_index()
out=['caught','bowled','lbw','stumped','caught and bowled','hit wicket']
bowl=delivery[delivery['dismissal_kind'].isin(out)]
bowl=bowl.groupby('bowler')['dismissal_kind'].count().sort_values(ascending=False).head(10).reset_index()
bowl
# Out:
#             bowler  dismissal_kind
# 0       SL Malinga             154
# 1         A Mishra             134
# 2  Harbhajan Singh             127
# 3        PP Chawla             126
# 4         DJ Bravo             122
# 5          B Kumar             111
# 6          A Nehra             106
# 7    R Vinay Kumar             103
# 8           Z Khan             102
# 9         R Ashwin             100

# %%
mat=delivery.groupby(['batsman','bowler'])['batsman_runs'].sum().reset_index()
mat=mat[mat['bowler'].isin(["SL Malinga","A Mishra","Harbhajan Singh","PP Chawla","DJ Bravo","B Kumar","A Nehra","R Vinay Kumar","Z Khan","R Ashwin"])]
mat=mat[mat['batsman'].isin(["SK Raina","V Kohli","RG Sharma","G Gambhir","DA Warner","RV Uthappa","CH Gayle","S Dhawan","MS Dhoni","AB de Villiers"])]
mat=mat.pivot_table(index='batsman',columns='bowler',values='batsman_runs')
sns.heatmap(mat)

# %%
deliver=delivery.groupby('bowler')['batsman_runs'].sum().sort_values().reset_index()
over=delivery.groupby('bowler')['ball'].count().reset_index()
mask2=delivery[delivery['over']>=16]
mask3=mask2.groupby('bowler')['ball'].count().reset_index()
mask4=mask2.groupby('bowler')['batsman_runs'].sum().reset_index()
mask5=mask3.merge(mask4,left_on='bowler',right_on='bowler')
mask5=mask5[mask5['ball']>200]
mask5['ball']=(mask5['batsman_runs']/mask5['ball'])*6
mask5=mask5.rename(columns={'ball':'economy'})
mask5.sort_values('economy')
# Out:
#               bowler    economy  batsman_runs
# 248       SL Malinga   6.777143          1186
# 254        SP Narine   6.876506           761
# 76      DE Bollinger   7.041322           284
# 199         R Ashwin   7.044855           445
# 161         MA Starc   7.057143           247
# 90          DW Steyn   7.317308           761
# 157   M Muralitharan   7.584507           359
# 293       WD Parnell   7.682243           274
# 101  Harbhajan Singh   7.744186           333
# 48             B Lee   7.884146           431
# 46           B Kumar   7.938462           946
# 88       DS Kulkarni   7.963636           438
# 168   MJ McClenaghan   8.018018           445
# 62         CH Morris   8.031496           510
# 137        KK Cooper   8.058394           368
# 85         DP Nannes   8.091743           294
# 195        PP Chawla   8.208589           446
# 200         R Bhatia   8.288136           326
# 77          DJ Bravo   8.291525          1223
# ...

# %%
# Out:
# batsman         bowler
# A Ashish Reddy  A Nehra              7
#                 AB Dinda             9
#                 AD Mathews          25
#                 AD Russell           4
#                 Anureet Singh        2
#                 Azhar Mahmood        2
#                 B Kumar              1
#                 BW Hilfenhaus        2
#                 CH Morris           11
#                 DJ Bravo            24
#                 Harbhajan Singh     11
#                 Imran Tahir          2
#                 J Botha              0
#                 JEC Franklin         3
#                 JP Duminy            1
#                 JP Faulkner          2
#                 KA Pollard           3
#                 KK Cooper            8
#                 M Kartik             6
#                 M Morkel             5
#                 MG Johnson           7
#                 MM Patel             0
#                 MM Sharma            7
# ...

# %%
match
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
team=match.groupby(['team1','team2'])[['win_by_runs']].count().reset_index()
team2=match.groupby(['team1','team2'])[['win_by_wickets']].count().reset_index()
team3=team.merge(team2,left_on=['team1','team2'],right_on=['team1','team2'])
team3
# Out:
#                            team1                        team2  win_by_runs  \
# 0            Chennai Super Kings              Deccan Chargers            8
# 1            Chennai Super Kings             Delhi Daredevils           11
# 2            Chennai Super Kings              Kings XI Punjab            9
# 3            Chennai Super Kings         Kochi Tuskers Kerala            2
# 4            Chennai Super Kings        Kolkata Knight Riders           11
# 5            Chennai Super Kings               Mumbai Indians           10
# 6            Chennai Super Kings                Pune Warriors            4
# 7            Chennai Super Kings             Rajasthan Royals            9
# 8            Chennai Super Kings  Royal Challengers Bangalore           10
# 9            Chennai Super Kings          Sunrisers Hyderabad            3
# 10               Deccan Chargers          Chennai Super Kings            2
# ...
